# %% [markdown]
# # Before you start :
#    - These exercises are related to the Subsetting and Descriptive Stats lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
# import libraries here
import pandas as pd
import numpy as np

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### In this challenge we will use the `Temp_States.csv` file.
#
# #### First import it into a data frame called `temp`.

# %%
# YOUR CODE HERE
temp=(pd.read_csv("Temp_States.csv"))

# %% [markdown]
# #### Print `temp`

# %%
# your solution here
print(temp)
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the Temp dataframe. What type of data do we have? Comment your result.

# %%
# YOUR CODE HERE

# the types are strings and float, as expected
temp.dtypes
temp.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   City         7 non-null      str
#  1   State        7 non-null      str
#  2   Temperature  7 non-null      float64
# dtypes: float64(1), str(2)
# memory usage: 300.0 bytes

# %% [markdown]
# #### Select the rows where state is New York

# %%
# YOUR CODE HERE
temp[temp["State"]=="New York"]
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average of the temperature of cities in New York?

# %%
# YOUR CODE HERE

temp[temp["State"]=="New York"]["Temperature"].mean()
# Out:
# np.float64(10.74074074074074)

# %% [markdown]
# #### We want to know cities and states with Temperature above 15 degress Celcius

# %%
# your answer here
temp[temp["Temperature"] > 15][["City", "State"]]
# Out:
#        City        State
# 0       NYC     New York
# 3  Hartford  Connecticut
# 5    Treton   New Jersey
# 6    Newark   New Jersey

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degress Celcius

# %%
# YOUR CODE HERE
temp.loc[temp["Temperature"] > 15]["City"]
# Out:
# 0         NYC
# 3    Hartford
# 5      Treton
# 6      Newark
# Name: City, dtype: str

# %% [markdown]
# #### We want to know which cities have a temperature above 15 degrees Celcius and below 20 degrees Celcius
#
# *Hint: First write the condition then select the rows.*

# %%
# YOUR CODE HERE

temp[(temp["Temperature"] > 15) & (temp["Temperature"] < 20)]["City"]
# Out:
# 0         NYC
# 3    Hartford
# Name: City, dtype: str

# %%
temp['State'].value_counts()
# Out:
# State
# New York       3
# Connecticut    2
# New Jersey     2
# Name: count, dtype: int64

# %% [markdown]
# #### Find the mean and the standard deviation of the temperature of each state.
#
# *Hint: Use functions from Data Manipulation lesson*

# %%
# YOUR CODE HERE
temp.groupby("State")["Temperature"].mean()
# Out:
# State
# Connecticut    15.833333
# New Jersey     21.111111
# New York       10.740741
# Name: Temperature, dtype: float64

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Load the `employee.csv` file into a DataFrame. Call the dataframe `employee`

# %%
# YOUR CODE HERE
employee=pd.read_csv("Employee.csv")

# %% [markdown]
# #### Explore the data types of the Temp dataframe. Comment your results

# %%
# YOUR CODE HERE
employee.dtypes
employee.info()

#it might be more useful converting the "gender" and other values into boolean or int types.
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        9 non-null      str
#  1   Department  9 non-null      str
#  2   Education   9 non-null      str
#  3   Gender      9 non-null      str
#  4   Title       9 non-null      str
#  5   Years       9 non-null      int64
#  6   Salary      9 non-null      int64
# dtypes: int64(2), str(5)
# memory usage: 636.0 bytes

# %% [markdown]
# #### Show visually the frequency distribution (histogram) of the employee dataset. In few words describe these histograms?

# %%
employee
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %%
# your answer here
# The histograms only show the numeric values of the dataframe. Therefore, Years and Salary.
# the most experienced ones in the company have been there for 8 years (2). There are 3 people that were in the company for 2 years. There is nobody in the country who's been in the company for 5 and 6 yers. The rest is one person for each experience year.
# The Salary ranges between 30 and 70. The analysts earn 30-35, the associates earn 55-60 and the VP are earning 70.

# %%
# YOUR CODE HERE
employee.hist(figsize=(10,8))
# Out:
# array([[<Axes: title={'center': 'Years'}>,
#         <Axes: title={'center': 'Salary'}>]], dtype=object)

# %%
# YOUR CODE HERE
import matplotlib.pyplot as plt

employee.hist(bins=20, figsize=(10,8))

plt.show()

# %% [markdown]
# #### What's the average salary in this company?

# %%
# YOUR CODE HERE

employee["Salary"].mean()
# Out:
# np.float64(48.888888888888886)

# %% [markdown]
# #### What's the highest salary?

# %%
# YOUR CODE HERE
employee["Salary"].max()
# Out:
# np.int64(70)

# %% [markdown]
# #### What's the lowest salary?

# %%
# YOUR CODE HERE
employee["Salary"].mean()
# Out:
# np.float64(48.888888888888886)

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
# YOUR CODE HERE
employee[employee["Salary"]==employee["Salary"].min()]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give all the information about an employee called David?

# %%
# YOUR CODE HERE
david="David"
employee[employee["Name"]==david]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give only David's salary?

# %%
# YOUR CODE HERE
employee[employee["Name"]==david]["Salary"]
# Out:
# 2    30
# Name: Salary, dtype: int64

# %% [markdown]
# #### Print all the rows where job title is associate

# %%
# YOUR CODE HERE

employee[employee["Title"]=="associate"]
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe
#
# ##### Tip : There are 2 ways to do it. Do it both ways

# %%
# YOUR CODE HERE
employee.head(3)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
# YOUR CODE HERE
employee[:3]
employee.iloc[:3]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find the employees who's title is associate and the salary above 55?

# %%
# YOUR CODE HERE
employee[(employee["Title"]=="associate")&(employee["Salary"]>55)]
# Out:
#     Name Department Education Gender      Title  Years  Salary
# 7  Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Group the employees based on their number of years of employment. What are the average salaries in each group?

# %%
# YOUR CODE HERE
employee.groupby("Years")["Salary"].mean()
# Out:
# Years
# 1    35.000000
# 2    38.333333
# 3    55.000000
# 4    35.000000
# 7    60.000000
# 8    70.000000
# Name: Salary, dtype: float64

# %% [markdown]
# ####  What is the average Salary per title?

# %%
# YOUR CODE HERE
employee.groupby("Title")["Salary"].mean()
# Out:
# Title
# VP           70.000000
# analyst      32.500000
# associate    56.666667
# Name: Salary, dtype: float64

# %% [markdown]
# #### Show a visual summary of the data using boxplot. What Are the First and Third Quartiles? Comment your results.
#
# * Hint : Quantiles vs Quartiles*
# In Probability and Statistics, quantiles are cut points dividing the range of a probability distribution into continuous intervals with equal probabilities. When division is into four parts the values of the variate corresponding to 25%, 50% and 75% of the total distribution are called quartiles.

# %%
# YOUR CODE HERE
employee.boxplot(figsize=(8,6))
# Out:
# <Axes: >

# %%
# print first quartile here
employee["Salary"].quantile(0.25)
# Out:
# np.float64(35.0)

# %%
# print third quartile here
employee["Salary"].quantile(0.75)   # Q3
# Out:
# np.float64(60.0)

# %% [markdown]
# #### Is the mean salary per gender different?

# %%
# your answer here
# Yes
employee[employee["Gender"]=="M"]["Salary"].mean()==employee[employee["Gender"]=="F"]["Salary"].mean()
# Out:
# np.False_

# %%
print(employee[employee["Gender"]=="M"]["Salary"].mean())
print(employee[employee["Gender"]=="F"]["Salary"].mean())
# Out:
# 50.0
# 47.5

# %% [markdown]
# #### Find the minimum, mean and the maximum of all numeric columns for each Department.
#
# ##### Hint: Use functions from Data Manipulation lesson

# %%
# your answer here
employee.groupby("Department")[["Years", "Salary"]].agg(["min", "mean", "max"])
# Out:
#            Years               Salary
#              min      mean max    min   mean max
# Department
# HR             2  4.666667   8     30  45.00  70
# IT             1  4.500000   8     30  48.75  70
# Sales          2  2.500000   3     55  55.00  55

# %% [markdown]
# ### Bonus Question
#
# #### For each department, compute the difference between the maximal salary and the minimal salary.
#
# ##### * Hint: try using `agg` or `apply` and `lambda`*

# %%
# your answer here
employee.groupby("Department")["Salary"].agg(lambda x: x.max() - x.min())
# Out:
# Department
# HR       40
# IT       40
# Sales     0
# Name: Salary, dtype: int64

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the Orders.csv dataset. Name your dataset orders

# %%
# your answer here
orders=pd.read_csv("Orders.csv")

# %% [markdown]
# #### Explore your dataset by looking at the data types and the summary statistics. Comment your results

# %%
# your answer here
orders.head()
# Out:
#    Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0           0     536365    85123A  2010     12    3     8
# 1           1     536365     71053  2010     12    3     8
# 2           2     536365    84406B  2010     12    3     8
# 3           3     536365    84029G  2010     12    3     8
# 4           4     536365    84029E  2010     12    3     8
#
#                            Description  Quantity          InvoiceDate  \
# 0   white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                  white metal lantern         6  2010-12-01 08:26:00
# 2       cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# 3  knitted union flag hot water bottle         6  2010-12-01 08:26:00
# 4       red woolly hottie white heart.         6  2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  amount_spent
# 0       2.55       17850  United Kingdom         15.30
# 1       3.39       17850  United Kingdom         20.34
# ...

# %%
orders.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 397924 entries, 0 to 397923
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    397924 non-null  int64
#  1   InvoiceNo     397924 non-null  int64
#  2   StockCode     397924 non-null  str
#  3   year          397924 non-null  int64
#  4   month         397924 non-null  int64
#  5   day           397924 non-null  int64
#  6   hour          397924 non-null  int64
#  7   Description   397924 non-null  str
#  8   Quantity      397924 non-null  int64
#  9   InvoiceDate   397924 non-null  str
#  10  UnitPrice     397924 non-null  float64
#  11  CustomerID    397924 non-null  int64
#  12  Country       397924 non-null  str
#  13  amount_spent  397924 non-null  float64
# dtypes: float64(2), int64(8), str(4)
# memory usage: 42.5 MB

# %%
# your answer here
orders.dtypes
# Out:
# Unnamed: 0        int64
# InvoiceNo         int64
# StockCode           str
# year              int64
# month             int64
# day               int64
# hour              int64
# Description         str
# Quantity          int64
# InvoiceDate         str
# UnitPrice       float64
# CustomerID        int64
# Country             str
# amount_spent    float64
# dtype: object

# %% [markdown]
# ####  What is the average Purchase Price?

# %%
# your answer here
orders["amount_spent"].mean()
# Out:
# np.float64(22.394748504739596)

# %% [markdown]
# #### What were the highest and lowest purchase prices?

# %%
# your answer here
orders["amount_spent"].min()
# Out:
# np.float64(0.0)

# %%
# in order to check if thats a legit purchase and not an outlier
orders[orders["amount_spent"]==0].head()

# minimum purchase >0
orders[orders["amount_spent"]>0]["amount_spent"].min()
# Out:
# np.float64(0.001)

# %%
# your answer here
orders["amount_spent"].max()
# Out:
# np.float64(168469.6)

# %% [markdown]
# #### Select all the customers we have in Spain

# %%
# your answer here
orders[orders["Country"]=="Spain"].head()
# Out:
#       Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250        6421     536944     22383  2010     12    5    12
# 4251        6422     536944     22384  2010     12    5    12
# 4252        6423     536944     20727  2010     12    5    12
# 4253        6424     536944     20725  2010     12    5    12
# 4254        6425     536944     20728  2010     12    5    12
#
#                   Description  Quantity          InvoiceDate  UnitPrice  \
# 4250  lunch bag suki  design         70  2010-12-03 12:20:00       1.65
# 4251  lunch bag pink polkadot       100  2010-12-03 12:20:00       1.45
# 4252  lunch bag  black skull.        60  2010-12-03 12:20:00       1.65
# 4253  lunch bag red retrospot        70  2010-12-03 12:20:00       1.65
# 4254      lunch bag cars blue       100  2010-12-03 12:20:00       1.45
#
#       CustomerID Country  amount_spent
# 4250       12557   Spain         115.5
# 4251       12557   Spain         145.0
# ...

# %% [markdown]
# #### How many customers do we have in Spain?
# ##### Hint : Use value_counts()

# %%
# your answer here
orders["Country"].value_counts()["Spain"]
# Out:
# np.int64(2485)

# %%
# name of orders
(orders["Country"]=="Spain").count()
# Out:
# np.int64(397924)

# %% [markdown]
# #### Select all the customers who have bought more than 50 items ?

# %%
# your answer here
orders.groupby("CustomerID")["Quantity"].sum()[lambda x: x > 50]
# Out:
# CustomerID
# 12346    74215
# 12347     2458
# 12348     2341
# 12349      631
# 12350      197
#          ...
# 18278       66
# 18281       54
# 18282      103
# 18283     1397
# 18287     1586
# Name: Quantity, Length: 4091, dtype: int64

# %% [markdown]
# #### Select orders from Spain that are above 50 items

# %%
# your answer here
orders[orders["Country"]=="Spain"].groupby("CustomerID")["Quantity"].sum()[lambda x: x > 50]
# Out:
# CustomerID
# 12354     530
# 12417     267
# 12421     484
# 12442     182
# 12445      62
# 12448     243
# 12450     128
# 12454    1006
# 12455     566
# 12462     536
# 12484    2191
# 12502     820
# 12507     905
# 12510     353
# 12538     191
# 12539    2067
# 12540    6685
# 12541     680
# 12544     136
# 12545     523
# 12546     633
# 12547     134
# 12550     569
# 12551     100
# 12556     358
# 12557    4384
# 12596     474
# 12597    2236
# 17097     459
# Name: Quantity, dtype: int64

# %% [markdown]
# #### Select all free orders

# %%
# your answer here
orders[orders["amount_spent"]==0].head()
# Out:
#        Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 6914         9302     537197     22841  2010     12    7    14
# 22539       33576     539263     22580  2010     12    4    14
# 25379       40089     539722     22423  2010     12    2    13
# 29080       47068     540372     22090  2011      1    4    16
# 29082       47070     540372     22553  2011      1    4    16
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 6914   round cake tin vintage green         1  2010-12-05 14:02:00        0.0
# 22539  advent calendar gingham sack         4  2010-12-16 14:36:00        0.0
# 25379      regency cakestand 3 tier        10  2010-12-21 13:45:00        0.0
# 29080       paper bunting retrospot        24  2011-01-06 16:41:00        0.0
# 29082        plasters in tin skulls        24  2011-01-06 16:41:00        0.0
#
#        CustomerID         Country  amount_spent
# 6914        12647         Germany           0.0
# ...

# %% [markdown]
# #### Select all orders that are 'lunch bag'
# #### Hint: Use string functions

# %%
# your answer here
orders[orders["Description"].str.contains("LUNCH BAG", case=False, na=False)].head()
# Out:
#      Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 93           93     536378     20725  2010     12    3     9
# 172         174     536385     22662  2010     12    3     9
# 354         363     536401     22662  2010     12    3    11
# 359         368     536401     20725  2010     12    3    11
# 360         369     536401     22382  2010     12    3    11
#
#                      Description  Quantity          InvoiceDate  UnitPrice  \
# 93       lunch bag red retrospot        10  2010-12-01 09:37:00       1.65
# 172  lunch bag dolly girl design        10  2010-12-01 09:56:00       1.65
# 354  lunch bag dolly girl design         1  2010-12-01 11:21:00       1.65
# 359      lunch bag red retrospot         1  2010-12-01 11:21:00       1.65
# 360   lunch bag spaceboy design          2  2010-12-01 11:21:00       1.65
#
#      CustomerID         Country  amount_spent
# 93        14688  United Kingdom         16.50
# 172       17420  United Kingdom         16.50
# ...

# %% [markdown]
# #### Select all orders that are made in 2011 and are 'lunch bag'

# %%
# your answer here
orders["InvoiceDate"]=pd.to_datetime(orders["InvoiceDate"])
orders[(orders["Description"].str.contains("LUNCH BAG", case=False, na=False)) & (orders["InvoiceDate"].dt.year == 2011)].head()
# Out:
#        Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 26340       42678     540015     20725  2011      1    2    11
# 26341       42679     540015     20726  2011      1    2    11
# 26512       42851     540023     22382  2011      1    2    12
# 26513       42852     540023     20726  2011      1    2    12
# 26860       43616     540098     22384  2011      1    2    15
#
#                       Description  Quantity         InvoiceDate  UnitPrice  \
# 26340     lunch bag red retrospot        10 2011-01-04 11:40:00       1.65
# 26341          lunch bag woodland        10 2011-01-04 11:40:00       1.65
# 26512  lunch bag spaceboy design          2 2011-01-04 12:58:00       1.65
# 26513          lunch bag woodland         1 2011-01-04 12:58:00       1.65
# 26860     lunch bag pink polkadot         1 2011-01-04 15:50:00       1.65
#
#        CustomerID         Country  amount_spent
# 26340       13319  United Kingdom         16.50
# ...

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
# your answer here
import matplotlib.pyplot as plt

orders_spain = orders[orders["Country"] == "Spain"]

orders_spain["amount_spent"].hist(bins=30)

plt.xlabel("Amount Spent")
plt.ylabel("Frequency")
plt.title("Frequency Distribution of Amount Spent in Spain")

plt.show()

# %% [markdown]
# #### Select all orders made in the month of August

# %%
# your answer here
orders[orders["InvoiceDate"].dt.month == 8].head()
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 199475      285421     561904     22075  2011      8    1     8
# 199476      285422     561904    85049E  2011      8    1     8
# 199477      285423     561905     21385  2011      8    1     9
# 199478      285424     561905    84970L  2011      8    1     9
# 199479      285425     561905    84970S  2011      8    1     9
#
#                               Description  Quantity         InvoiceDate  \
# 199475       6 ribbons elegant christmas         96 2011-08-01 08:30:00
# 199476          scandinavian reds ribbons       156 2011-08-01 08:30:00
# 199477    ivory hanging decoration  heart        24 2011-08-01 09:31:00
# 199478   single heart zinc t-light holder        12 2011-08-01 09:31:00
# 199479  hanging heart zinc t-light holder        12 2011-08-01 09:31:00
#
#         UnitPrice  CustomerID         Country  amount_spent
# 199475       1.45       17941  United Kingdom        139.20
# ...

# %% [markdown]
# #### Select how many orders are made by countries in the month of August
# ##### Hint: Use value_counts()

# %%
# your answer here
orders[orders["InvoiceDate"].dt.month == 8]["Country"].value_counts()
# Out:
# Country
# United Kingdom     23105
# Germany              795
# EIRE                 593
# France               569
# Netherlands          280
# Switzerland          267
# Spain                252
# Belgium              194
# Israel               171
# Channel Islands      140
# Australia            107
# Italy                 95
# Austria               88
# Norway                77
# Finland               61
# Malta                 55
# Portugal              41
# Sweden                40
# Unspecified           23
# Iceland               22
# Poland                17
# Denmark               16
# Canada                 5
# Name: count, dtype: int64

# %% [markdown]
# #### What's the  average amount of money spent by country

# %%
# your answer here
orders.groupby("Country")["amount_spent"].mean().head()
# Out:
# Country
# Australia    116.895620
# Austria       25.624824
# Bahrain       32.258824
# Belgium       20.283772
# Brazil        35.737500
# Name: amount_spent, dtype: float64

# %% [markdown]
# #### What's the most expensive item?

# %%
# your answer here
orders.loc[orders["UnitPrice"].idxmax(), "Description"]
# Out:
# 'postage'

# %% [markdown]
# #### What was the average amount spent per year ?

# %%
# your answer here


orders.groupby(orders["InvoiceDate"].dt.year)["amount_spent"].mean()
# Out:
# InvoiceDate
# 2010    21.892733
# 2011    22.430074
# Name: amount_spent, dtype: float64
